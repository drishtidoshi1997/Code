# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import yfinance as yf

# %% [markdown]
# ### NIFTY 50 INDEX
#
# #####Importing symbols(tickers) from Wikipedia using pd_html
# #####Using tickers for importing data from Yahoo Finance ie NIFTY 50 Indexes

# %%
tickers = pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[2]['Symbol']
print(tickers)
# Out:
# 0       ADANIENT
# 1     ADANIPORTS
# 2     APOLLOHOSP
# 3     ASIANPAINT
# 4       AXISBANK
# 5     BAJAJ-AUTO
# 6     BAJFINANCE
# 7     BAJAJFINSV
# 8           BPCL
# 9     BHARTIARTL
# 10     BRITANNIA
# 11         CIPLA
# 12     COALINDIA
# 13      DIVISLAB
# 14       DRREDDY
# 15     EICHERMOT
# 16        GRASIM
# 17       HCLTECH
# 18      HDFCBANK
# 19      HDFCLIFE
# 20    HEROMOTOCO
# 21      HINDALCO
# 22    HINDUNILVR
# 23     ICICIBANK
# 24    INDUSINDBK
# 25          INFY
# 26           ITC
# 27      JSWSTEEL
# 28     KOTAKBANK
# 29            LT
# 30          LTIM
# 31           M&M
# 32        MARUTI
# 33     NESTLEIND
# 34          NTPC
# 35          ONGC
# 36     POWERGRID
# 37      RELIANCE
# 38       SBILIFE
# 39          SBIN
# 40     SUNPHARMA
# 41    TATAMOTORS
# 42     TATASTEEL
# 43           TCS
# 44    TATACONSUM
# 45         TECHM
# 46         TITAN
# 47    ULTRACEMCO
# 48           UPL
# 49         WIPRO
# Name: Symbol, dtype: object

# %% [markdown]
# ## Data Preparation (Iterating using For Loop for all 50 Tickers)
# #### Importing data from Yahoo Finance using yf library
# #### Setting end date as present (latest) and start date as present - last 15 years using timedelta function from datetime library
# #### Setting interval as 1 day, pre-opening,post-closing as false
# #### Prev_Close(New column) = Shifting 1 row of Close below
# #### Prev_Volume(New column) = Shifting 1 row of Volume below
#
# Why not considering Volume?
# Volume is associated with previous day close fundamentally

# %%
from datetime import datetime
for ticker in tickers[0:1]:
  end_date = datetime.now()
  start_date = end_date - timedelta(days=15*365)

  history = yf.download(ticker+".NS", start_date, end=end_date , interval='1d' , prepost=False)
  history = history.loc[: , ['Open', 'Close', 'Volume']]
  history['Prev_Close'] = history.loc[: , 'Close'].shift(1)
  history['Prev_Volume'] = history.loc[: , 'Volume'].shift(1)

  display(history)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open        Close   Volume   Prev_Close  Prev_Volume
# Date
# 2008-07-31    49.048019    48.837265   293407          NaN          NaN
# 2008-08-01    48.523052    50.017483   581190    48.837265     293407.0
# 2008-08-04    49.814396    49.661118   150187    50.017483     581190.0
# 2008-08-05    49.124657    50.542450   142802    49.661118     150187.0
# 2008-08-06    45.446053    49.538498   379853    50.542450     142802.0
# ...                 ...          ...      ...          ...          ...
# 2023-07-21  2410.000000  2416.300049  2280563  2419.750000    1564275.0
# 2023-07-24  2430.000000  2418.199951  1113193  2416.300049    2280563.0
# 2023-07-25  2428.000000  2466.649902  3017555  2418.199951    1113193.0
# 2023-07-26  2472.449951  2470.750000  4021773  2466.649902    3017555.0
# 2023-07-27  2470.750000  2428.399902  2243944  2470.750000    4021773.0
#
# [3694 rows x 5 columns]

# %% [markdown]
# ## Changing Date time
# ### Converting each datetime object in the "datetimes" list to a pandas Timestamp object, and then use the weekday() method to get the integer representation of the weekday (0 for Monday, 1 for Tuesday, ..., 6 for Sunday). The resulting weekdays are stored in the "weekdays" list.

# %%
datetimes = history.index.values
weekdays = []


# Converting datetime into string
for dt in datetimes:
  #print(dt)
  dt = datetime.strptime(str(dt) ,'%Y-%m-%dT%H:%M:%S.000000000')
  weekdays.append(dt.weekday())

 # Adding new column Weekday for assigning week days number
history['Weekday'] = weekdays

display(history)
# Out:
#                    Open        Close   Volume   Prev_Close  Prev_Volume  \
# Date
# 2008-07-31    49.048019    48.837265   293407          NaN          NaN
# 2008-08-01    48.523052    50.017483   581190    48.837265     293407.0
# 2008-08-04    49.814396    49.661118   150187    50.017483     581190.0
# 2008-08-05    49.124657    50.542450   142802    49.661118     150187.0
# 2008-08-06    45.446053    49.538498   379853    50.542450     142802.0
# ...                 ...          ...      ...          ...          ...
# 2023-07-21  2410.000000  2416.300049  2280563  2419.750000    1564275.0
# 2023-07-24  2430.000000  2418.199951  1113193  2416.300049    2280563.0
# 2023-07-25  2428.000000  2466.649902  3017555  2418.199951    1113193.0
# 2023-07-26  2472.449951  2470.750000  4021773  2466.649902    3017555.0
# 2023-07-27  2470.750000  2428.399902  2243944  2470.750000    4021773.0
#
#             Weekday
# Date
# 2008-07-31        3
# 2008-08-01        4
# 2008-08-04        0
# 2008-08-05        1
# 2008-08-06        2
# ...             ...
# 2023-07-21        4
# 2023-07-24        0
# 2023-07-25        1
# 2023-07-26        2
# 2023-07-27        3
#
# [3694 rows x 6 columns]

# %% [markdown]
# ## Dropping rows NaN values
# ### Converting Infinite values ie number divided by 0 to NaN : by using replace(np.inf,np.nan)
# ### Dropping these NaN values: using drop.na()

# %%
history= history.replace(np.inf , np.nan).dropna()

# %% [markdown]
# ## Machine Learning
# ### Using Linear Regression to predict Close price
# ### Data: Train, Test sampling split should be sequentially because it is a Time-Series Data a

# %%
from sklearn.linear_model import LinearRegression

y = history['Close']
x = history.drop(['Close' , 'Volume'], axis = 1)

# variable num_test = 365 to determine how many data points
# will be used for testing the model's performance

num_test = 365
# Train data: All rows except last 365 days
# Test data: All columns starting from last 365 days

x_train = x[:-1*num_test]
y_train = y[:-1*num_test]
x_test = x[-1*num_test:]
y_test = y[-1*num_test:]

#(Extracting number of Samples and number of Features)
print(x_train.shape , y_train.shape , x_test.shape, y_test.shape)
# Out:
# (3328, 4) (3328,) (365, 4) (365,)

# %%
model = LinearRegression()
model = model.fit(x_train , y_train)
preds = model.predict(x_test)
print(type(preds))
print(type(y_test))

print(ticker)

print(y_test)
print(preds)
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>
# ADANIENT
# Date
# 2022-02-07    1731.800049
# 2022-02-08    1716.000000
# 2022-02-09    1783.150024
# 2022-02-10    1786.099976
# 2022-02-11    1764.300049
#                  ...
# 2023-07-21    2416.300049
# 2023-07-24    2418.199951
# 2023-07-25    2466.649902
# 2023-07-26    2470.750000
# 2023-07-27    2428.399902
# Name: Close, Length: 365, dtype: float64
# [1763.46710756 1737.75070648 1722.16429785 1792.11670242 1780.01604079
#  1756.43946172 1655.80341129 1747.05564329 1745.44879592 1736.65096262
#  3847.52397442 3840.01073422 3832.79588962 3835.09651128 3837.78244953
#  3862.82804078 3657.60264766 3643.86752828 3654.11017808 3726.6995837
#  3625.57897396 3648.34349144 3552.2508122  3463.22952149 3456.61203807
#  3446.16719581 3439.45002005 3372.64460245 2800.49365773 2931.23406708
#  2986.55279155 2222.19209767 1537.09936107 1583.92762071 1574.27984672
#  1831.68777586 2168.56105659 1866.49361048 1851.14644551 1727.11397114
#  1764.09791837 1797.74844559 1800.45178479 1697.10286384 1625.88587077
#  1559.3793612  1397.03529197 1395.22050303 1311.78857774 1176.37076543
#  1388.90610612 1540.9276884  1640.99456958 1916.50980743 2007.8407004
#  2046.4405773  1923.03475776 1907.49387524 1877.23963105 1749.64428508
#  1850.18692722 1868.83825604 1864.18986402 1820.48312727 1830.95615735
#  1809.73455763 1797.3363351  1743.62721226 1727.81689174 1604.11690484
#  1761.44048321 1753.47539235 1720.18535892 1703.31149098 1764.89115879
#  1805.23266295 1810.28926635 1853.04531605 1873.99052793 1887.08022878
#  1852.35216097 1857.12299918 1846.79496703 1806.56871119 1806.57920488
#  1851.16509372 1850.75257357 1861.64232883 1932.00710792 1922.53789398
#  1841.73014829 1931.06658802 1923.54143103 1895.55217789 1900.25593956
#  1907.94890098 1996.92436704 1966.18088882 1923.48245342 1896.41052148
#  1906.50291548 1891.94871336 1980.50765482 2362.59074736 2666.712195
#  2464.79092694 2551.80125488 2558.64121514 2536.27105357 2494.69163055
#  2499.63336121 2512.62362584 2456.20719989 2454.0178467  2444.95799742
#  2447.33295721 2440.02611403 2458.75561521 2494.39506785 2469.29635915
#  2465.53911387 2494.54668564 2511.45434782 2418.269426   2423.25747789
#  2416.97437192 2398.62399144 2227.77730789 2312.31150688 2288.01726006
#  2348.14641802 2398.66320546 2393.89245081 2392.74272698 2402.77567208
#  2403.27963244 2388.81374212 2419.43555883 2429.44974805 2395.10499759
#  2370.59553725 2389.48635091 2414.98050328 2425.2098574  2429.46988788
#  2419.45124596 2425.75191203 2426.01280083 2472.77205954 2474.43278247]

# %%
len(y_test)
len(preds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-ebe21c778264> in <cell line: 1>()
# ----> 1 len(y_test)
#       2 len(preds)
#
# <ipython-input-42-c749498ba9d8> in len(self)
#       1 def len(self):
# ----> 2     return len(self.processed_file_names())
#       3     self.processed_file_names()
#       4 plt.figure(figsize=(15, 5))
#       5 plt.plot(range(len(y_test)), y_test, 'blue', label='Actual')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'processed_file_names'

# %%
print(y_test)
# Out:
# Date
# 2022-02-07    1731.800049
# 2022-02-08    1716.000000
# 2022-02-09    1783.150024
# 2022-02-10    1786.099976
# 2022-02-11    1764.300049
#                  ...
# 2023-07-21    2416.300049
# 2023-07-24    2418.199951
# 2023-07-25    2466.649902
# 2023-07-26    2470.750000
# 2023-07-27    2428.399902
# Name: Close, Length: 365, dtype: float64

# %%
#print(preds)
print(type(preds))
#len(preds)
print(preds.shape)
# Out:
# <class 'numpy.ndarray'>
# (365,)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-8202224fea92> in <cell line: 7>()
#       5
#       6 # If preds is a Pandas Series, convert it to a NumPy array
# ----> 7 preds_np = preds.values
#       8
#       9 # If y_test is a Python list, convert it to a NumPy array
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'
